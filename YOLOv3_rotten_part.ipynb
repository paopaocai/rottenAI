# %% [markdown]
# # Yolo v3 Rotten Part Detection

# %%
from google.colab import drive
drive.mount('/content/drive/') # Using Google Drive
# Out:
# Mounted at /content/drive/

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg

# %%
import os

os.chdir("/content/drive/MyDrive/") # Using Google Drive
os.chdir("rottenAI/darknet-rotten-part/")

# %% [markdown]
# # Download Darknet-53, pretrained weights, network structure

# %%
# !make
# Out:
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:1004:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !python voc_label.py
# !cat 2007_train.txt 2007_val.txt  > train.txt

# %% [markdown]
# #Train the model
# #### before training, please edit the following files accordingly
#
# *   cfg/yolov3-voc.cfg
# *   cfg/yolov3-voc-test.cfg
# *   data/voc.names
# *   data/coco.names
# *   cfg/voc.data
# *   MakeFile

# %%
# !./darknet detector train cfg/voc.data cfg/yolov3-voc.cfg darknet53.conv.74

# %% [markdown]
# # Test 1 images

# %%
# !./darknet detector test cfg/voc.data cfg/yolov3-voc-test.cfg backup/yolov3-voc.backup VOCdevkit/VOC2007/JPEGImages/24.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32  0.299 BFLOPs
#     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32  0.177 BFLOPs
#     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     4 res    1                 208 x 208 x  64   ->   208 x 208 x  64
#     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     8 res    5                 104 x 104 x 128   ->   104 x 104 x 128
#     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#    10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
# ...

# %%
lena = mpimg.imread('predictions.jpg') 

plt.imshow(lena) 
plt.axis('off') 
plt.show()

# %% [markdown]
# # Continue train the model

# %%
# !./darknet detector train cfg/voc.data cfg/yolov3-voc.cfg backup/yolov3-voc.backup -dont_show

# %% [markdown]
# # Calculate mAP

# %%
# !./darknet detector valid cfg/voc.data cfg/yolov3-voc-test.cfg backup/yolov3-voc.backup -out "" -gpu 0 -thresh .5

# %%
# !python2 compute_map.py
# Out:
# Reading annotation for 1/8
# Saving cached annotations to ./annots.pkl
# (array([0.999999, 0.999999, 0.999999]), array([1.        , 0.5       , 0.33333333]), 0.9999990000010001)
